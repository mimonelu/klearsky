# %%
import sqlite3
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual style
sns.set_theme(style="whitegrid")
# %matplotlib inline

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
import sqlite3
import pandas as pd

# --- Display options: remove truncation ---
pd.set_option('display.max_colwidth', None)     # show full column content
pd.set_option('display.max_columns', None)      # show all columns
pd.set_option('display.width', None)            # avoid wrapping
pd.set_option('display.max_rows', None)         # optional: show all rows

# --- Load DB ---
db_path = 'user_activity.db'
conn = sqlite3.connect(db_path)

query = "SELECT * FROM activity_logs ORDER BY timestamp DESC"
df = pd.read_sql_query(query, conn)

conn.close()

print(f"Total Rows: {len(df)}")
df.head(15)     # <- will now display full JSON, untruncated
# Out:
# Total Rows: 17
#    id                          user_did                   timestamp     action_type input_text moderation_mode                                popup_session_id                                                                                                                                                                      metadata_json
# 0  17  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-03 16:37:27.411310  POST_PUBLISHED          b        STANDARD  did:plc:2vhnujzchm3cfrbccid6fram_1764779845866  {"final_mode": "STANDARD", "cid": "bafyreiai7aibiyqn4vh7nhyzipjsfho7gmd4litewxwfgiak62q3xg6x44", "uri": "at://did:plc:2vhnujzchm3cfrbccid6fram/app.bsky.feed.post/3m73vdy53xn2g"}
# 1  16  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-03 16:37:27.298392    POPUP_CLOSED                   STANDARD  did:plc:2vhnujzchm3cfrbccid6fram_1764779845866                                                                                                                               {"duration_ms": 1421, "timestamp_ms": 1764779847287}
# 2  15  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-03 16:37:27.296885  POST_SUBMITTED          b        STANDARD  did:plc:2vhnujzchm3cfrbccid6fram_1764779845866                                                                                                                                                         {"final_mode": "STANDARD"}
# 3  14  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-03 16:37:27.260500  DRAFT_AUTOSAVE          b        STANDARD  did:plc:2vhnujzchm3cfrbccid6fram_1764779845866                                                                                                                                                                      {"length": 1}
# 4  13  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-03 16:37:25.875720    POPUP_OPENED                   STANDARD  did:plc:2vhnujzchm3cfrbccid6fram_1764779845866                                                                                                                                                    {"timestamp_ms": 1764779845866}
