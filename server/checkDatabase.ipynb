# %%
import sqlite3
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual style
sns.set_theme(style="whitegrid")
# %matplotlib inline

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
# Connect to the SQLite database
db_path = 'user_activity.db'
conn = sqlite3.connect(db_path)

# Query the entire table
query = "SELECT * FROM activity_logs ORDER BY timestamp DESC"
df = pd.read_sql_query(query, conn)

# Close connection
conn.close()

# Show the first few rows
print(f"Total Rows: {len(df)}")
df.head()
# Out:
# Total Rows: 32
#    id                          user_did                   timestamp  \
# 0  32  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-02 15:40:23.083535
# 1  31  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-02 15:40:22.382710
# 2  30  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-02 15:32:32.942084
# 3  29  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-02 15:32:27.336714
# 4  28  did:plc:2vhnujzchm3cfrbccid6fram  2025-12-02 15:32:19.691106
#
#          action_type                                         input_text  \
# 0  REWRITE_SUGGESTED                           I fucking hate your idea
# 1     DRAFT_AUTOSAVE                           I fucking hate your idea
# 2     DRAFT_AUTOSAVE  I do not like your idea at all I actually hate...
# 3     DRAFT_AUTOSAVE  I do not like your idea at all I actually hate it
# 4     DRAFT_AUTOSAVE                    I do not like your idea at all
#
#   moderation_mode                                      metadata_json
# 0         REWRITE  {"original": "I fucking hate your idea", "sugg...
# 1         REWRITE                                     {"length": 24}
# 2         REWRITE                                     {"length": 62}
# 3         REWRITE                                     {"length": 49}
# 4         REWRITE                                     {"length": 31}
